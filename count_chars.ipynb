# %% [markdown]
# <a href="https://colab.research.google.com/github/mohit-kumar396/Python-Programming-Practice/blob/main/count_chars.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s=input("Enter the character in string:- ")
# Out:
# Enter the character in string:- ser#$12@

# %%
count=0

# %%
for i in range(0,len(s)):
  count += 1

# %%
print(count)
# Out:
# 8
