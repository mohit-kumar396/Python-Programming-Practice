# %% [markdown]
# <a href="https://colab.research.google.com/github/mohit-kumar396/Python-Programming-Practice/blob/main/check_element_in_list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s1=input("Enter the value in string:-")
# Out:
# Enter the value in string:-w23r4

# %%
s2=input("Enter the value in string:-")
print(s2 in s1)
# Out:
# Enter the value in string:-r4
# True
