# %% [markdown]
# <a href="https://colab.research.google.com/github/mohit-kumar396/Python-Programming-Practice/blob/main/add_5_to_odd_elements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Jab tumhe list ke element ke saath uska index bhi chahiye, tab enumerate() use karte hain.
# Example to understand concept :-

# %%
lst = ["apple", "banana", "mango"]

for index, item in enumerate(lst):
    print(index, item)
#  enumerate() har iteration mein index + item deta hai
# Out:
# 0 apple
# 1 banana
# 2 mango

# %%
# Real Question:- add 5 to every odd element of list using enumerate

# %%
lst=[10,15,20,25,30]
for index,item in enumerate(lst):
  if lst[index]%2!=0:
    lst[index]+=5
lst
# Out:
# [10, 20, 20, 30, 30]
