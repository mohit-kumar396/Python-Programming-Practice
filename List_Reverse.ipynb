# %% [markdown]
# <a href="https://colab.research.google.com/github/mohit-kumar396/Python-Programming-Practice/blob/main/List_Reverse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=list(map(int,input("Enter the numbers in a: ").split()))
# Out:
# Enter the numbers in a: 1 2 4 5

# %%
rev_list=[]
for i in range(len(a)-1,-1,-1):
  rev_list.append(a[i])

# %%
rev_list
# Out:
# [5, 4, 2, 1]
