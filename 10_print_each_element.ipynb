# %% [markdown]
# <a href="https://colab.research.google.com/github/mohit-kumar396/Python-Programming-Practice/blob/main/10_print_each_element.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lst=list(map(int, input("Enter the value in list:- ").split()))
# Out:
# Enter the value in list:- 1 2 3 4 5 6 7 2 3

# %%
for i in range(len(lst)):
  print(lst[i], end=" ")
# Out:
# 1 2 3 4 5 6 7 2 3
