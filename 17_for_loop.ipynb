# %% [markdown]
# <a href="https://colab.research.google.com/github/mohit-kumar396/Python-Programming-Practice/blob/main/17_for_loop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Q1. Replace every occurence of 20 by 99 using for loop

# %%
lst1=[10,20,40,20,50]

# %%
for i in range(len(lst1)):
  if lst1[i]==20:
    lst1[i]=99

# %%
lst1
# Out:
# [10, 99, 40, 99, 50]
