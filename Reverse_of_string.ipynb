# %% [markdown]
# <a href="https://colab.research.google.com/github/mohit-kumar396/Python-Programming-Practice/blob/main/Reverse_of_string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s="Mohit"
print(s)
# Out:
# Mohit

# %%
type(s)
# Out:
# str

# %%
result=""

# %%
for i in range(len(s)-1,-1,-1):
  result+=s[i]
# note:-  stop value excluded hota hai range me
# while start value included hota hai

# %%
print(result)
# Out:
# tihoM

# %%
#Note :- Python ki string characters ko sequence (ordered collection) ki tarah store karti hai, isliye har character k
# index hota hai.
