# %% [markdown]
# <a href="https://colab.research.google.com/github/mohit-kumar396/Python-Programming-Practice/blob/main/15_Enumerate_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lst=[5,10,15,20,25]

# %%
for index,value in enumerate(lst):
  if lst[index] % 2 != 0:
    lst[index]+=5
print(lst)
# Out:
# [10, 10, 20, 20, 30]
